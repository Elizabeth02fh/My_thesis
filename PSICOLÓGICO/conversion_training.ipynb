# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/TESIS_PYTHON/PSICOLÓGICO/balanced_psico_selection.csv')

# %%
df.sample(3)
# Out:
#      s_academica  c_espacios  Diagnostico
# 46             1           4            1
# 266            1           4            1
# 22             2           4            0

# %%
#PSICOLÓGICA: Reemplazando con valores ordinales
df['c_espacios'].replace((0,1,2,3,4),('No me alcanza tiempo','Ausencia de lugares para sentirte mejor','Jugar videojuegos','Bailar','Jugar algún deporte'), inplace =  True)
df['s_academica'].replace((0,1,2,3,4),( 'Dejas a última hora las tareas','Dificultad para concentrarte','Dificultad con el material de estudio', 'Exigencia del curso','Carga de horario'), inplace = True)

#TARGET: Reemplazando con valores binarios
df['Diagnostico'].replace((0,1),('No Saludable', 'Saludable'),inplace = True)

# %%
df.sample(3)
# Out:
#                         s_academica c_espacios   Diagnostico
# 21     Dificultad para concentrarte     Bailar  No Saludable
# 192    Dificultad para concentrarte     Bailar     Saludable
# 125  Dejas a última hora las tareas     Bailar  No Saludable

# %%
df.to_csv('/content/drive/MyDrive/TESIS_PYTHON/ACTIVIDADFISICA/cate_balanced_activity_selection.csv', index=False)
